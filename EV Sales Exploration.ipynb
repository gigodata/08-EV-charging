# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./Resources/IEA-EV-dataEV salesCarsHistorical.csv')
usdf = data.loc[(data['region'] =='USA') & (data['powertrain'] == 'BEV')]
usdf
# Out:
#     region    category parameter  mode powertrain  year      unit   value
# 783    USA  Historical  EV sales  Cars        BEV  2010  Vehicles    1200
# 784    USA  Historical  EV sales  Cars        BEV  2011  Vehicles    9800
# 787    USA  Historical  EV sales  Cars        BEV  2012  Vehicles   15000
# 788    USA  Historical  EV sales  Cars        BEV  2013  Vehicles   48000
# 791    USA  Historical  EV sales  Cars        BEV  2014  Vehicles   63000
# 792    USA  Historical  EV sales  Cars        BEV  2015  Vehicles   71000
# 795    USA  Historical  EV sales  Cars        BEV  2016  Vehicles   87000
# 796    USA  Historical  EV sales  Cars        BEV  2017  Vehicles  100000
# 799    USA  Historical  EV sales  Cars        BEV  2018  Vehicles  240000
# 801    USA  Historical  EV sales  Cars        BEV  2019  Vehicles  240000
# 802    USA  Historical  EV sales  Cars        BEV  2020  Vehicles  230000
# 805    USA  Historical  EV sales  Cars        BEV  2021  Vehicles  470000
# ...

# %%
xval = usdf['year']
yval = usdf['value']

plt.plot(xval, yval)
